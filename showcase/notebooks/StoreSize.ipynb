# %%
import fsspec
import matplotlib.pyplot as plt
import s3fs
import xarray as xr
import numpy as np
import zarr

# %%
from xcube.core.store import new_data_store
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from xcube.core.store import new_data_store
#
# ModuleNotFoundError: No module named 'xcube.core'

# %%
zarr_store = new_data_store('ccizarr')

zarr_store.getsize()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 zarr_store = new_data_store('ccizarr')
#       3 zarr_store.getsize()
#
# NameError: name 'new_data_store' is not defined

# %%
ds = xr.open_zarr('http://cci-ke-o.s3.jc.rl.ac.uk/esacci/ESACCI-BIOMASS-L4-AGB-MERGED-100m-2010-2018-fv2.0.zarr')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 3, lat: 157500, lon: 405000, nv: 2)
# Coordinates:
#   * lat        (lat) float64 80.0 80.0 80.0 80.0 ... -60.0 -60.0 -60.0 -60.0
#     lat_bnds   (lat, nv) float64 dask.array<chunksize=(810, 2), meta=np.ndarray>
#   * lon        (lon) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#     lon_bnds   (lon, nv) float64 dask.array<chunksize=(810, 2), meta=np.ndarray>
#   * time       (time) datetime64[ns] 2010-07-02 2017-07-02 2018-07-02
#     time_bnds  (time, nv) datetime64[ns] dask.array<chunksize=(3, 2), meta=np.ndarray>
# Dimensions without coordinates: nv
# Data variables:
#     agb        (time, lat, lon) float32 dask.array<chunksize=(3, 810, 810), meta=np.ndarray>
#     agb_se     (time, lat, lon) float32 dask.array<chunksize=(3, 810, 810), meta=np.ndarray>
# Attributes: (12/53)
#     Conventions:                  CF-1.7
#     EPSG:                         4326
# ...
